# %%
M = int(input())
setM = set(map(int, input().split()))
N = int(input())
setN = set(map(int, input().split()))
uni = setM.union(setN)
inter = setM.intersection(setN)
a =  list(uni.difference(inter))
a.sort()
for i in a:
    print(i)
