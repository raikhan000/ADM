# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
n = int(input())
set_english = set(input().split())
b = int(input())
set_french = set(input().split())
union_set = set_english.union(set_french)
print(len(union_set))
