# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
n  = int(input())
a = set()
for i in range(n):
    s = input()
    if s in a:
        continue
    else:
        a.add(s)
print(len(a))
