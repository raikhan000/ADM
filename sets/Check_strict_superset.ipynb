# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
A = set(input().split())
n = int(input())
cnt = 0
for i in range(n):
    B = set(input().split())
    if A.issuperset(B):
       cnt+=1
if cnt == n:
    print("True")
else:
    print("False")
