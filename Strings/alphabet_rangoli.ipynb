# %%
import string
def print_rangoli(size):
    # your code goes here
    n = 4 * size -3
    string1 = "abcdefghijklmnopqrstuvwxyz"
    
    for i in range(size-1, 0,-1):
        s = "-".join(string1[i:size])
        print((s[::-1]+s[1:]).center(n, "-"))
    for i in range(size):
        s = "-".join(string1[i:size])
        print((s[::-1]+s[1:]).center(n, "-"))
