# %%
def print_formatted(number):
    # your code goes here
    a = len(f'{bin(number)}'[2:]) + 1
    for i in range(1,number+1):
        print(f'{i}'.rjust(a-1) + f'{oct(i)}'[2:].rjust(a) + f'{hex(i)}'[2:].upper().rjust(a)+ f'{bin(i)}'[2:].rjust(a))
