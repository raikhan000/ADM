# %%
import numpy as np
N, M = map(int, input().split())
arr2 = []
for i in range(N):
    s = list(map(int, input().split()))
    arr2.append(s)
print(np.transpose(arr2))
my_array = np.array(arr2)
print(my_array.flatten())
