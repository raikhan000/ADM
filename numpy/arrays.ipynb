# %%
import numpy

def arrays(arr):
    # complete this function
    # use numpy.array
    arr = list(map(float, arr))
    return numpy.flip(arr, 0)

arr = input().strip().split(' ')
result = arrays(arr)
print(result)
